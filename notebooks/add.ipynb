# %%
def add(a, b):
    return a + b

# %%
add(2,3)

# %%
add(10,12)

# %%
add(16484974,373929384)

# %%
add(1.2,3.4)

# %%
add(5, 'hello')

# %%
add(-5,20)

# %%
add(-67,-45)

# %%
add((1/2), (1/3))

# %%
add(2 + 3j, 4 + 5j)

# %%
add('good','morning')

# %%
add(6,4 + 5j)

# %%
add(1,3.14)

# %%
add(3.5,'hello')
