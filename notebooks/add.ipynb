# %%
def add(a, b):
    return a + b

# %%
add(2,3)
# Out:
# 5

# %%
add(10,12)
# Out:
# 22

# %%
add(16484974,373929384)
# Out:
# 390414358

# %%
add(1.2,3.4)
# Out:
# 4.6

# %%
add(5, 'hello')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 add(5, 'hello')
#
# Cell In[2], line 2, in add(a, b)
#       1 def add(a, b):
# ----> 2     return a + b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
add(-5,20)
# Out:
# 15

# %%
add(-67,-45)
# Out:
# -112

# %%
add((1/2), (1/3))
# Out:
# 0.8333333333333333

# %%
add(2 + 3j, 4 + 5j)
# Out:
# (6+8j)

# %%
add('good','morning')
# Out:
# 'goodmorning'

# %%
add(6,4 + 5j)
# Out:
# (10+5j)

# %%
add(1,3.14)
# Out:
# 4.140000000000001

# %%
add(3.5,'hello')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 add(3.5,'hello')
#
# Cell In[2], line 2, in add(a, b)
#       1 def add(a, b):
# ----> 2     return a + b
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
